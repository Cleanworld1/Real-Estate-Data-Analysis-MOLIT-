# %%
import requests
import sys
from lxml import etree

__SERVICE_KEY_DATAGO__ = 'ZW7sQn/lro4dNI4Glzow/3oLOfWii0CB8RaskqxODpYUq9ZJxs4Ujqp/GyJv7OfIWhf5dkiGBhA3oWgZVSTdPg=='
__SERVICE_KEY_KIPRISPLUS__ = 'KugS/3lYf=/rsMpC/XxYw85eeLkpNh0HEYfqse4XHfQ='

url_dict = {
    "getWordSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getWordSearch",                                   # 일반검색 - 단어(폐기예정)
    "getAdvancedSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getAdvancedSearch",                           # 항목별검색 - 전체검색
    "freeSearchInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/freeSearchInfo",                                  # 항목별검색 - 자유검색
    "applicationNumberSearchInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/applicationNumberSearchInfo",        # 항목별검색 - 출원번호 검색
    "cpcSearchInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/cpcSearchInfo",                                    # 항목별검색 - CPC 검색
    "getBibliographyDetailInfoSearch":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/freeSearchInfo",                 # 서지정보 - 서지상세정보(공공데이터 포털 연계)
    "getBibliographySumryInfoSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getBibliographySumryInfoSearch", # 서지정보 - 서지요약정보
    "patentIpcInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentIpcInfo",                                    # 서지정보 - IPC 정보
    "patentCpcInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentCpcInfo",                                    # 서지정보 - CPC 정보
    "patentRndInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentRndInfo",                                    # 서지정보 - 국가연구개발사업정보
    "patentApplicantInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentApplicantInfo",                        # 서지정보 - 출원인정보
    "patentInventorInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentInventorInfo",                          # 서지정보 - 발명자정보
    "patentFamilyInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentFamilyInfo",                              # 서지정보 - 패밀리정보
    "getPubFullTextInfoSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getPubFullTextInfoSearch",             # 도면/전문 - 공개전문PDF
    "getAnnFullTextInfoSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getAnnFullTextInfoSearch",             # 도면/전문 - 공고전문PDF
    "getRevisionFullTextInfoSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getRevisionFullTextInfoSearch",   # 도면/전문 - 정정공고PDF(폐기예정)
    "getReprsntFloorPlanInfoSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getReprsntFloorPlanInfoSearch",   # 도면/전문 - 대표도면
    "revisionfullDocPDFInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/revisionfullDocPDFInfo",                  # 도면/전문 - 정정공고PDF_V2
    "getChangeInfoSearch":"http://plus.kipris.or.kr/kipo-api/kipi/patUtiModInfoSearchSevice/getChangeInfoSearch",                       # 부가기능 - 변동정보
    "patentTransferInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentTransferInfo",                          # 부가기능 - 변동정보2
    "patentBiblioInfo":"http://plus.kipris.or.kr/openapi/rest/patUtiModInfoSearchSevice/patentBiblioInfo",                              # 부가기능 - 서지정보 조회(과제번호)
}

params_dict = {
    "getWordSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, 'word':'센서', 'year':'5', 'patent':'false', 'numOfRows':'70', 'pageNo':'3', },
    "getAdvancedSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, 'applicant':'루닛', 'numOfRows':'500', },
    "freeSearchInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "applicationNumberSearchInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "cpcSearchInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getBibliographyDetailInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getBibliographySumryInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentIpcInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentCpcInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentRndInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentApplicantInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentInventorInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentFamilyInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getPubFullTextInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getAnnFullTextInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getRevisionFullTextInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getReprsntFloorPlanInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "revisionfullDocPDFInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "getChangeInfoSearch": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentTransferInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
    "patentBiblioInfo": {'ServiceKey':__SERVICE_KEY_KIPRISPLUS__, },
}

print(url_dict["getAdvancedSearch"], params_dict["getAdvancedSearch"])

response = requests.get(url_dict["getAdvancedSearch"], params=params_dict["getAdvancedSearch"])
response.content

# %%
currentNode = etree.fromstring(response.content) # 현재 root 가리킴

if 'body' not in [x.tag for x in currentNode.getchildren()]:
    print("부적절한 공공데이터 불러오기ㅠㅠ")
    sys.exit(0)

print("Available Response... Parsing...")


def iter_nodes(element):
    #어떤 공공데이터도 이 함수로 파싱할 수 있음!
    result = {}
    if len(element)>0:  # Empty Node가 아닌 경우
        children_list = sorted(list(set([x.tag for x in element.getchildren()])))   # 자식 노드 (Unique values)
        for children in children_list:
            siblings = element.findall(children)
            if len(siblings)>1:
                sibling_list = []
                for i in siblings:
                    sibling_list.append(iter_nodes(i))
                result[str(children)] = sibling_list
            else:
                result[str(children)] = iter_nodes(siblings[0])
        return result
    else:   # Empty Node인 경우
        return element.text
# Out:
# Available Response... Parsing...

# %%
result = iter_nodes(currentNode)
result

# %%
from lxml import etree
import pandas as pd

root = etree.fromstring(response.content)

#temp = root.findall(".//item")


# Column 추출할 때에는
column_list=[x.tag for x in root.find("body").find("items").find("item")]
print(column_list)

#getWordSearch - 일반검색 - 1. 단어(폐기예정)
column_getWordSearch = [
    'applicantName',
    'applicationDate', 
    'applicationNumber', 
    'astrtCont', 
    'bigDrawing', 
    'drawing', 
    'indexNo', 
    'inventionTitle', 
    'ipcNumber', 
    'openDate', 
    'openNumber', 
    'publicationDate', 
    'publicationNumber', 
    'registerDate', 
    'registerNumber', 
    'registerStatus'
    ]
column_getAdvancedSearch = [
    'applicantName', 
    'applicationDate', 
    'applicationNumber', 
    'astrtCont', 
    'bigDrawing', 
    'drawing', 
    'indexNo', 
    'inventionTitle', 
    'ipcNumber', 
    'openDate', 
    'openNumber', 
    'publicationDate', 
    'publicationNumber', 
    'registerDate', 
    'registerNumber', 
    'registerStatus'
    ]


df = pd.DataFrame(columns=column_getAdvancedSearch)
# Out:
# ['applicantName', 'applicationDate', 'applicationNumber', 'astrtCont', 'bigDrawing', 'drawing', 'indexNo', 'inventionTitle', 'ipcNumber', 'openDate', 'openNumber', 'publicationDate', 'publicationNumber', 'registerDate', 'registerNumber', 'registerStatus']

# %%
result = []
for items in root.find('.//body').findall('items'):
    for item in items:
        temp = {}
        for column in column_getWordSearch:
            if item.find(column) is not None:
                temp[column] = item.find(column).text
        result.append(temp)

# %%
df = pd.DataFrame(result, columns=column_getWordSearch)
df
# Out:
#                         applicantName applicationDate applicationNumber  \
# 0                             주식회사 루닛        20200121     1020200007785
# 1                             주식회사 루닛        20210119     1020210007191
# 2                             주식회사 루닛        20210119     1020210007193
# 3                             주식회사 루닛        20191004     1020190123067
# 4                             주식회사 루닛        20191029     1020190135420
# ..                                ...             ...               ...
# 68                            주식회사 루닛        20190322     1020190032699
# 69                            주식회사 루닛        20190319     1020190031099
# 70                            주식회사 루닛        20131209     1020130152089
# 71                    가부시키가이샤 리쿠시루 닛탄        19890216     1019890001814
# 72  노링스이산쇼 산시.곤츄노교기즈츠켄큐쇼쵸가 다이효스루 닛본고쿠        19960126     1019960705382
#
#                                             astrtCont  \
# ...

# %%
df = df[df['applicantName'].str.contains('주식회사 루닛')]
df
# Out:
#    applicantName applicationDate applicationNumber  \
# 0        주식회사 루닛        20200121     1020200007785
# 1        주식회사 루닛        20210119     1020210007191
# 2        주식회사 루닛        20210119     1020210007193
# 3        주식회사 루닛        20191004     1020190123067
# 4        주식회사 루닛        20191029     1020190135420
# ..           ...             ...               ...
# 66       주식회사 루닛        20190320     1020190031662
# 67       주식회사 루닛        20190320     1020190031664
# 68       주식회사 루닛        20190322     1020190032699
# 69       주식회사 루닛        20190319     1020190031099
# 70       주식회사 루닛        20131209     1020130152089
#
#                                             astrtCont  \
# 0   본 개시는 신경망을 이용하여 의료 영상 및 메타데이터의 관계를 기계학습하고, 의료영...
# 1   본 개시는 의료 데이터의 특징점을 취합하여 기계 학습하는 방법 및 장치에 대한 것으...
# 2   본 개시는 의료 데이터의 특징점을 취합하여 기계 학습하는 방법 및 장치에 대한 것으...
# 3   이미지 분석 방법 및 시스템이 제공된다. 상기 이미지 분석 방법은 트레이닝 조직 슬...
# 4   신경망 학습 방법 및 그 장치가 제공된다. 상기 신경망 학습 방법은 컴퓨팅 장치에서...
# ...
